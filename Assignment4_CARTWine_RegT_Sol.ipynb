# %% [markdown]
# <a href="https://colab.research.google.com/github/danielbauer1979/ML_656/blob/main/Assignment4_CARTWine_RegT_Sol.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Assignment 4: CART
#
# Apply Classification tree to the wine quality data set.

# %% [markdown]
# Import relevant libraries:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import graphviz
import pydot
from io import StringIO

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier, export_graphviz
from sklearn.metrics import mean_squared_error,confusion_matrix, classification_report, roc_curve, auc

# %% [markdown]
# And introduce a function for printing a tree:

# %%
import pydot
from IPython.display import Image
def print_tree(estimator, features, class_names=None, filled=True):
  tree = estimator
  names = features
  color = filled
  classn = class_names
  dot_data = StringIO()
  export_graphviz(estimator, out_file=dot_data,feature_names=features,class_names=classn, filled=filled)
  graph = pydot.graph_from_dot_data(dot_data.getvalue())
  return(graph)

# %% [markdown]
# Get the data:

# %%
# !git clone https://github.com/danielbauer1979/ML_656.git
# Out:
# fatal: destination path 'ML_656' already exists and is not an empty directory.

# %%
wine = pd.read_csv('ML_656/winequality-red.csv', sep = ';')
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# And, in order to have a classification problem, let's call wines with scores above 6 high quality wines (true=1=positives) and below as low wuality wines (fale=0=negatives).

# %%
wine['quality'] = wine['quality'] > 6
wine['quality'].describe()
# Out:
# count      1599
# unique        2
# top       False
# freq       1382
# Name: quality, dtype: object

# %% [markdown]
# Let's set a seed so that our data is reproducible and let's split our data:

# %%
np.random.seed(42)
train, test = train_test_split(wine, test_size = 0.5)
test, val = train_test_split(test, test_size = 0.5)
X_train = train.drop(columns = ['quality']).values
y_train = train['quality'].values
X_val = val.drop(columns = ['quality']).values
y_val = val['quality'].values
X_test = test.drop(columns = ['quality']).values
y_test = test['quality'].values

# %% [markdown]
# Let's start our basic tree classifier, where we set the minimal cell size to 5 and a minimal node impurity decrease to 0.0001. If this value is higher, we don't get a very deep tree... Note that we are using a Regressor, which essentially means we are using mean-squared error (closely related to misclassification error) for building the tree.

# %%
wine_tree = DecisionTreeRegressor(min_samples_split=5,min_impurity_decrease=0.0001)
wine_tree.fit(X_train, y_train)
graph, = print_tree(wine_tree, features= train.drop(columns = ['quality']).columns)
Image(graph.create_png())

# %% [markdown]
# And let's generate some predictions based on the test set:

# %%
wine_tree_preds = wine_tree.predict(X_val)

# %%
fpr, tpr, threshold = roc_curve(val['quality'], wine_tree_preds)
roc_auc = auc(fpr, tpr)
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# So the AUC is about 79%, which is lower than for the logistic regression method.

# %% [markdown]
# So let's consider trees of different size, and let's evaluate the AUC for each of them based on the validation set:

# %%
AUC_scores = []
scores = []
for i in range(3,36,3):
    wine_tree_try = DecisionTreeRegressor(min_samples_split=5,min_impurity_decrease=0.0001,max_leaf_nodes=i)
    wine_tree_try.fit(X_train, y_train)
    wine_tree_try_preds = wine_tree_try.predict(X_val)
    fpr, tpr, threshold = roc_curve(val['quality'], wine_tree_try_preds)
    AUC_scores.append(auc(fpr, tpr))
plt.plot(range(3,36,3),AUC_scores)

# %% [markdown]
# Based on this plot, a tree with 12 leaf nodes seems appropriate.
#
# Let's train a tree with 12 nodes:

# %%
wine_tree_final = DecisionTreeRegressor(min_samples_split=5,min_impurity_decrease=0.0001,max_leaf_nodes=12)
wine_tree_final.fit(X_train, y_train)
graph, = print_tree(wine_tree_final, features= train.drop(columns = ['quality']).columns)
Image(graph.create_png())

# %% [markdown]
# And let's check the predictions based on the holdout (test) set:

# %%
wine_tree_final_preds = wine_tree_final.predict(X_test)
wine_tree_final_preds_labels = wine_tree_final_preds > 0.5

# %%
table = pd.DataFrame({'Quality':test.quality,'Predicted':wine_tree_final_preds_labels})
table.groupby(['Quality','Predicted']).size().unstack('Quality')
# Out:
# Quality    False  True
# Predicted
# False        324     32
# True          23     21

# %%
fpr, tpr, threshold = roc_curve(test['quality'], wine_tree_final_preds)
roc_auc = auc(fpr, tpr)
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# So a decent performance, thoug worse than the logistic regression classifier.
